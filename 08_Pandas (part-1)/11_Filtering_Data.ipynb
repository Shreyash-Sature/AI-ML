# %%
# Filtering data

#eg : Filter cities whose aqi is > 150

# %%
import pandas as pd

# %%
#Creating DataFrame
df = pd.read_csv("globalAirQuality.csv")

# %%
#Filtering Data

df[df["aqi"]>220]

df[(df["aqi"]>150) & (df["temperature"]>30)]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 44     2025-11-06 14:25:17.554219      US  New York    40.713    -74.006
# 112    2025-11-09 10:25:17.554219      US  New York    40.713    -74.006
# 284    2025-11-16 14:25:17.554219      US  New York    40.713    -74.006
# 329    2025-11-18 11:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17589  2025-11-17 15:25:17.554219      FI  Helsinki    60.170     24.938
# 17665  2025-11-05 19:25:17.554219      CH    Zurich    47.377      8.542
# 17797  2025-11-11 07:25:17.554219      CH    Zurich    47.377      8.542
# 17821  2025-11-12 07:25:17.554219      CH    Zurich    47.377      8.542
# 17822  2025-11-12 08:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...
