# %% [markdown]
# # Handling Strings
# - .str.lower()  .str.upper()  .str.capitalize()
# - .str.strip()
# - .str.split()
# - .str.contains(val, case=False)

# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data .csv")

df["gender"].str.upper()

df["name"].str.split()
# Out:
# 0         [John, Doe]
# 1         [John, Doe]
# 2       [Jane, Smith]
# 3              [Alex]
# 4     [Maria, Garcia]
# 5           [Li, Wei]
# 6                 NaN
# 7       [Ahmed, Khan]
# 8       [Rachel, Lee]
# 9      [Carlos, Ruiz]
# 10     [Emily, Davis]
# Name: name, dtype: object

# %%
df["country"].str.contains("india", case=False) # checks if india is present in column (country) and case = False means irrespective of lower upper case
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7       NaN
# 8     False
# 9     False
# 10    False
# Name: country, dtype: object
