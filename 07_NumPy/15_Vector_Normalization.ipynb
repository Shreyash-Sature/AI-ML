# %%
import numpy as np

# %%
#normalize

arr = np.array([[1,2],[4,3]])

mean = np.mean(arr)
std_dav = np.std(arr)


print(f" mean : {mean}")
print()

print(f"standar daviationstd_dav)
print()

normalized_arr = (arr-mean)/std_dav
print(normalized_arr)
# Out:
#  mean : 2.5
#
# 1.118033988749895
#
# [[-1.34164079 -0.4472136 ]
#  [ 1.34164079  0.4472136 ]]
